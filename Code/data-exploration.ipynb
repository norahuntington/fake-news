# %%
from clean_data import get_data, speaker_dataframe, split_X_y, data_info
from plots import plot_year_month, words_counts, make_dictionary, plot_wordclouds

# %%
data = get_data()
# Out:
# /Users/honorahuntington/Galvanize/Capstone2/fake-news/fake news detection(FakeNewsNet)/clean_data.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'][i] = dt.strptime(data['date'][i][0], '%Y-%m-%d')
# /Users/honorahuntington/Galvanize/Capstone2/fake-news/fake news detection(FakeNewsNet)/clean_data.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['statement_len'][i] = len(data['statement'][i])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17324 entries, 0 to 17323
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     17324 non-null  object
#  1   speaker                  17324 non-null  object
#  2   statement                17324 non-null  object
#  3   sources                  17324 non-null  object
#  4   paragraph_based_content  17324 non-null  object
#  5   fullText_based_content   17324 non-null  object
#  6   label_fnn                17324 non-null  int64
#  7   year                     17324 non-null  int64
#  8   month                    17324 non-null  int64
#  9   statement_len            17324 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 1.3+ MB

# %%
data_info(data)
# Out:
# Number of total data points: 17324
# Number of data labeled real: 8767 ; percent real: 50.6%
# Number of data labeled fake: 8557 ; percent fake: 49.4%
#
# Years data spans: 2007 - 2020
#
# Number of unique speakers: 4212
# Number of statements made by top 20 speakers: 5208
#
# Average number of words per statement: 17.85
# Average number of characters per statement: 110.19

# %%
speaker_dataframe(data)
# Out:
#             speaker  statements  lies     %lies party
# 0      Donald Trump         786   561  0.713740     R
# 1      Barack Obama         602   151  0.250831     D
# 2    Facebook posts         565   488  0.863717
# 3          Bloggers         554   506  0.913357
# 4       Viral image         355   335  0.943662
# 5   Hillary Clinton         299    82  0.274247     D
# 6       Mitt Romney         206    85  0.412621     R
# 7      Scott Walker         201    93  0.462687     R
# 8       John McCain         184    79  0.429348     R
# 9       Chain email         181   162  0.895028
# 10       Rick Perry         172    79  0.459302     R
# 11   Bernie Sanders         169    44  0.260355     D
# 12       Rick Scott         163    71  0.435583     R
# 13      Marco Rubio         160    69  0.431250     R
# 14         Ted Cruz         142    93  0.654930     R
# 15        Joe Biden         120    47  0.391667     D
# 16   Chris Christie         102    35  0.343137     R
# ...

# %%
plot_year_month(data)

# %%
X, y = split_X_y(data)

# %%
real_words, real_counts = words_counts(X, y, 0)
fake_words, fake_counts = words_counts(X, y, 1)

fake_dictionary = make_dictionary(fake_words, fake_counts)
real_dictionary = make_dictionary(real_words, real_counts)

plot_wordclouds(fake_words, fake_counts, real_words, real_counts)
